# %%
import os
import pandas as pd

# %%
input_path = 'Excel/PTPCR_v1.xlsx'

# Read the Excel file
df = pd.read_excel(input_path)

# %%
filtered_df = df[(df['temperature'] > 94) | (df['temperature'] < 61)]
print(filtered_df)
# Out:
#          time  temperature
# 0       0.000        59.23
# 20      4.059        95.58
# 21      4.261        98.17
# 22      4.464        95.94
# 23      4.667        94.37
# ...       ...          ...
# 1603  325.297        94.28
# 1643  333.413        60.87
# 1671  339.097        94.17
# 1711  347.213        60.83
# 1712  347.416        60.37
#
# [96 rows x 2 columns]

# %%
filtered_df['time_difference'] = filtered_df['time'].diff()
print(filtered_df)
# Out:
#          time  temperature  time_difference
# 0       0.000        59.23              NaN
# 20      4.059        95.58            4.059
# 21      4.261        98.17            0.202
# 22      4.464        95.94            0.203
# 23      4.667        94.37            0.203
# ...       ...          ...              ...
# 1603  325.297        94.28            5.685
# 1643  333.413        60.87            8.116
# 1671  339.097        94.17            5.684
# 1711  347.213        60.83            8.116
# 1712  347.416        60.37            0.203
#
# [96 rows x 3 columns]
# /var/folders/dw/wsclfk4942z7826xf09yp3g80000gn/T/ipykernel_7857/3215446316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['time_difference'] = filtered_df['time'].diff()

# %%
# Corrected filter to ensure no NaNs and time_difference >= 0.5
cleaned_df = filtered_df[(filtered_df['time_difference'] >= 0.5) & (filtered_df['time_difference'].notna())]

print(cleaned_df)
# Out:
#          time  temperature  time_difference
# 20      4.059        95.58            4.059
# 54     10.954        60.69            6.287
# 68     13.795        94.36            2.638
# 98     19.880        60.95            6.085
# 112    22.721        94.44            2.638
# 142    28.806        60.81            6.085
# 156    31.646        94.11            2.638
# 185    37.528        60.86            5.882
# 200    40.571        94.15            2.840
# 230    46.657        60.63            6.086
# 247    50.107        94.38            3.247
# 277    56.193        60.89            6.086
# 293    59.441        95.09            3.248
# 326    66.136        60.97            6.493
# 342    69.383        94.41            3.045
# 375    76.078        60.55            6.695
# 394    79.934        95.12            3.653
# 429    87.034        60.87            6.897
# 447    90.689        94.48            3.451
# 480    97.385        60.91            6.493
# 500   101.445        94.79            3.857
# 538   109.156        60.80            7.508
# 557   113.012        95.19            3.653
# 593   120.317        60.85            7.101
# 614   124.580        94.10            4.060
# 651   132.088        60.88            7.508
# 672   136.351        94.17            4.060
# 709   143.859        60.88            7.508
# 729   147.919        94.42            3.857
# 765   155.225        60.68            7.306
# 786   159.487        94.47            4.060
# 823   166.995        60.62            7.508
# 844   171.258        94.18            4.060
# 880   178.564        60.98            7.306
# 901   182.826        94.11            4.060
# 937   190.132        60.81            7.306
# 959   194.597        94.09            4.263
# 996   202.105        60.57            7.508
# 1019  206.774        94.40            4.466
# 1057  214.484        60.60            7.710
# 1080  219.154        94.03            4.466
# 1118  226.865        60.62            7.711
# 1142  231.737        94.21            4.670
# 1180  239.448        60.93            7.711
# 1205  244.522        94.41            4.872
# 1245  252.639        60.53            8.117
# 1270  257.714        94.06            4.872
# 1309  265.628        60.67            7.914
# 1335  270.906        94.26            5.075
# 1375  279.022        60.56            8.116
py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['calculation'] = 34 / cleaned_df['time_difference']

# %%
import pandas as pd

# Assuming 'cleaned_df' is your DataFrame after filtering
# Reset the index to ensure it starts from 0 and is continuous
cleaned_df.reset_index(drop=True, inplace=True)

# Initialize the new columns with NaN
cleaned_df['heating rate'] = pd.NA
cleaned_df['cooling rate'] = pd.NA

# Assign 'time_difference' to 'heating time' on even indices and to 'cooling rate' on odd indices
for index, row in cleaned_df.iterrows():
    if index % 2 == 0:  # Check if the index is even
        cleaned_df.at[index, 'heating rate'] = row['calculation']
    else:  # Check if the index is odd
        cleaned_df.at[index, 'cooling rate'] = row['calculation']

print(cleaned_df)
# Out:
#        time  temperature  time_difference  calculation heating rate  \
# 0     4.059        95.58            4.059     8.376447     8.376447
# 1    10.954        60.69            6.287     5.407985         <NA>
# 2    13.795        94.36            2.638    12.888552    12.888552
# 3    19.880        60.95            6.085     5.587510         <NA>
# 4    22.721        94.44            2.638    12.888552    12.888552
# 5    28.806        60.81            6.085     5.587510         <NA>
# 6    31.646        94.11            2.638    12.888552    12.888552
# 7    37.528        60.86            5.882     5.780347         <NA>
# 8    40.571        94.15            2.840    11.971831    11.971831
# 9    46.657        60.63            6.086     5.586592         <NA>
# 10   50.107        94.38            3.247    10.471204    10.471204
# 11   56.193        60.89            6.086     5.586592         <NA>
# 12   59.441        95.09            3.248    10.467980     10.46798
# 13   66.136        60.97            6.493     5.236408         <NA>
# 14   69.383        94.41            3.045    11.165846    11.165846
# 15   76.078        60.55            6.695     5.078417         <NA>
# 16   79.934        95.12            3.653     9.307419     9.307419
# 17   87.034        60.87            6.897     4.929680         <NA>
# 18   90.689        94.48            3.451     9.852217     9.852217
# 19   97.385        60.91            6.493     5.236408         <NA>
# 20  101.445        94.79            3.857     8.815141     8.815141
# 21  109.156        60.80            7.508     4.528503         <NA>
# 22  113.012        95.19            3.653     9.307419     9.307419
# 23  120.317        60.85            7.101     4.788058         <NA>
# 24  124.580        94.10            4.060     8.374384     8.374384
# 25  132.088        60.88            7.508     4.528503         <NA>
# 26  136.351        94.17            4.060     8.374384     8.374384
# 27  143.859        60.88            7.508     4.528503         <NA>
# 28  147.919        94.42            3.857     8.815141     8.815141
# 29  155.225        60.68            7.306     4.653709         <NA>
# 30  159.487        94.47            4.060     8.374384     8.374384
# 31  166.995        60.62            7.508     4.528503         <NA>
# 32  171.258        94.18            4.060     8.374384     8.374384
# 33  178.564        60.98            7.306     4.653709         <NA>
# 34  182.826        94.11            4.060     8.374384     8.374384
# 35  190.132        60.81            7.306     4.653709         <NA>
# 36  194.597        94.09            4.263     7.975604     7.975604
# 37  202.105        60.57            7.508     4.528503         <NA>
# 38  206.774        94.40            4.466     7.613077     7.613077
# 39  214.484        60.60            7.710     4.409857         <NA>
# 40  219.154        94.03            4.466     7.613077     7.613077
# 41  226.865        60.62            7.711     4.409285         <NA>
# 42  231.737        94.21            4.670     7.280514     7.280514
# 43  239.448        60.93            7.711     4.409285         <NA>
# 44  244.522        94.41            4.872     6.978654     6.978654
# 45  252.639        60.53            8.117     4.188740         <NA>
# 46  257.714        94.06            4.872     6.978654     6.978654
# 47  265.628        60.67            7.914     4.296184         <NA>
# 48  270.906        94.26            5.075     6.699507     6.699507
# 49  279.022        60.56            8.116     4.189256         <NA>
# 50  284.301        94.03            5.075     6.699507     6.699507
# 51  292.214        60.77            7.913     4.296727         <NA>
# 52  297.696        94.36            5.279     6.440614     6.440614
# 53  305.812        60.71            8.116     4.189256         <NA>
# 54  311.496        94.37            5.481     6.203248     6.203248
# 55  319.612        60.96            8.116     4.189256         <NA>
# 56  325.297        94.28            5.685     5.980651     5.980651
# 57  333.413        60.87            8.116     4.189256         <NA>
# 58  339.097        94.17            5.684     5.981703     5.981703
# 59  347.213        60.83            8.116     4.189256         <NA>
#
#    cooling rate
# 0          <NA>
# 1      5.407985
# 2          <NA>
# 3       5.58751
# 4          <NA>
# 5       5.58751
# 6          <NA>
# 7      5.780347
# 8          <NA>
# 9      5.586592
# 10         <NA>
# 11     5.586592
# 12         <NA>
# 13     5.236408
# 14         <NA>
# 15     5.078417
# 16         <NA>
# 17      4.92968
# 18         <NA>
# 19     5.236408
# 20         <NA>
# 21     4.528503
# 22         <NA>
# 23     4.788058
# 24         <NA>
# 25     4.528503
# 26         <NA>
# 27     4.528503
# 28         <NA>
# 29     4.653709
# 30         <NA>
# 31     4.528503
# 32         <NA>
# 33     4.653709
# 34         <NA>
# 35     4.653709
# 36         <NA>
# 37     4.528503
# 38         <NA>
# 39     4.409857
# 40         <NA>
# 41     4.409285
# 42         <NA>
# 43     4.409285
# 44         <NA>
# 45      4.18874
# 46         <NA>
# 47     4.296184
# 48         <NA>
# 49     4.189256
# 50         <NA>
# 51     4.296727
# 52         <NA>
# 53     4.189256
# 54         <NA>
# 55     4.189256
# 56         <NA>
# 57     4.189256
# 58         <NA>
# 59     4.189256
# /var/folders/dw/wsclfk4942z7826xf09yp3g80000gn/T/ipykernel_7857/4135007064.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['heating rate'] = pd.NA
# /var/folders/dw/wsclfk4942z7826xf09yp3g80000gn/T/ipykernel_7857/4135007064.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['cooling rate'] = pd.NA

# %%
# # Drop rows only if both 'heating rate' and 'cooling rate' are NA
# cleaned_df.dropna(subset=['heating rate', 'cooling rate'], how='all', inplace=True)

# # Replace NA in both columns with a placeholder, e.g., 0
# cleaned_df['heating rate'].fillna(0, inplace=True)
# cleaned_df['cooling rate'].fillna(0, inplace=True)

# # Create a combined metric example
# cleaned_df['combined rate'] = cleaned_df['heating rate'].fillna(0) + cleaned_df['cooling rate'].fillna(0)


# print(cleaned_df)

# %%
# Extract the base name without extension
base_name = os.path.splitext(os.path.basename(input_path))[0]

# Create a new output filename using the base name
output_path = f'./Excel/{base_name}_output.xlsx'

# Write the cleaned dataframe to a new Excel file
cleaned_df.to_excel(output_path, index=False, engine='openpyxl')

# %%
# cleaned_df['heating rate'] = cleaned_df[(cleaned_df['calculation'] >= 5)]

# print(cleaned_df)
