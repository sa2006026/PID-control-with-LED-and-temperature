# %%
import os
import pandas as pd

# %%
input_path = './Excel/108um_20W.xlsx'

# Read the Excel file
df = pd.read_excel(input_path)

# %%
filtered_df = df[(df['temperature'] > 94) | (df['temperature'] < 61)]
print(filtered_df)
# Out:
#          time  temperature
# 0       0.000        59.86
# 25      5.071        94.53
# 26      5.274        94.42
# 67     13.590        60.90
# 68     13.793        60.86
# ...       ...          ...
# 1917  389.012        60.60
# 1918  389.216        60.58
# 1942  394.088        94.33
# 1943  394.291        94.35
# 1985  402.812        60.59
#
# [116 rows x 2 columns]

# %%
filtered_df['time_difference'] = filtered_df['time'].diff()
print(filtered_df)
# Out:
#          time  temperature  time_difference
# 0       0.000        59.86              NaN
# 25      5.071        94.53            5.071
# 26      5.274        94.42            0.203
# 67     13.590        60.90            8.316
# 68     13.793        60.86            0.203
# ...       ...          ...              ...
# 1917  389.012        60.60            8.522
# 1918  389.216        60.58            0.204
# 1942  394.088        94.33            4.872
# 1943  394.291        94.35            0.203
# 1985  402.812        60.59            8.521
#
# [116 rows x 3 columns]
# C:\Users\sa200\AppData\Local\Temp\ipykernel_3016\3215446316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['time_difference'] = filtered_df['time'].diff()

# %%
# Corrected filter to ensure no NaNs and time_difference >= 0.5
cleaned_df = filtered_df[(filtered_df['time_difference'] >= 0.5) & (filtered_df['time_difference'].notna())]

print(cleaned_df)
# Out:
#          time  temperature  time_difference
# 25      5.071        94.53            5.071
# 67     13.590        60.90            8.316
# 91     18.460        94.61            4.667
# 134    27.182        60.63            8.519
# 158    32.052        94.55            4.668
# 200    40.570        60.85            8.315
# 224    45.440        94.56            4.667
# 266    53.958        60.67            8.315
# 290    58.828        94.68            4.666
# 331    67.144        60.97            8.113
# 355    72.015        94.48            4.668
# 396    80.333        60.95            8.115
# 420    85.205        94.36            4.669
# 461    93.522        60.94            8.115
# 485    98.394        94.33            4.669
# 526   106.714        60.96            8.117
# 550   111.586        94.27            4.670
# 591   119.905        60.94            8.116
# 615   124.777        94.25            4.669
# 656   133.097        60.92            8.117
# 680   137.968        94.19            4.668
# 721   146.288        60.85            8.116
# 745   151.160        94.09            4.669
# 786   159.479        60.76            8.116
# 810   164.352        94.05            4.669
# 851   172.672        60.83            8.118
# 875   177.544        94.09            4.670
# 916   185.863        60.72            8.117
# 981   199.054        60.83           12.989
# 1005  203.926        94.11            4.668
# 1046  212.246        60.84            8.117
# 1070  217.118        94.05            4.669
# 1111  225.437        60.84            8.116
# 1135  230.309        94.01            4.669
# 1176  238.628        60.99            8.116
# 1200  243.501        94.07            4.669
# 1242  252.023        60.56            8.320
# 1267  257.098        94.45            4.872
# 1309  265.621        60.77            8.320
# 1334  270.696        94.50            4.872
# 1376  279.218        60.88            8.319
# 1401  284.294        94.53            4.873
# 1444  293.018        60.96            8.522
# 1468  297.890        94.53            4.872
# 1511  306.616        60.62            8.523
# 1536  311.691        94.43            4.872
# 1579  320.416        60.56            8.522
# 1604  325.491        94.40            4.872
# 1646  334.014        60.96            8.320
.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['calculation'] = 34 / cleaned_df['time_difference']

# %%
import pandas as pd

# Assuming 'cleaned_df' is your DataFrame after filtering
# Reset the index to ensure it starts from 0 and is continuous
cleaned_df.reset_index(drop=True, inplace=True)

# Initialize the new columns with NaN
cleaned_df['heating rate'] = pd.NA
cleaned_df['cooling rate'] = pd.NA

# Assign 'time_difference' to 'heating time' on even indices and to 'cooling rate' on odd indices
for index, row in cleaned_df.iterrows():
    if index % 2 == 0:  # Check if the index is even
        cleaned_df.at[index, 'heating rate'] = row['calculation']
    else:  # Check if the index is odd
        cleaned_df.at[index, 'cooling rate'] = row['calculation']

print(cleaned_df)
# Out:
#        time  temperature  time_difference  calculation heating rate  \
# 0     5.071        94.53            5.071     6.704792     6.704792
# 1    13.590        60.90            8.316     4.088504         <NA>
# 2    18.460        94.61            4.667     7.285194     7.285194
# 3    27.182        60.63            8.519     3.991079         <NA>
# 4    32.052        94.55            4.668     7.283633     7.283633
# 5    40.570        60.85            8.315     4.088996         <NA>
# 6    45.440        94.56            4.667     7.285194     7.285194
# 7    53.958        60.67            8.315     4.088996         <NA>
# 8    58.828        94.68            4.666     7.286755     7.286755
# 9    67.144        60.97            8.113     4.190805         <NA>
# 10   72.015        94.48            4.668     7.283633     7.283633
# 11   80.333        60.95            8.115     4.189772         <NA>
# 12   85.205        94.36            4.669     7.282073     7.282073
# 13   93.522        60.94            8.115     4.189772         <NA>
# 14   98.394        94.33            4.669     7.282073     7.282073
# 15  106.714        60.96            8.117     4.188740         <NA>
# 16  111.586        94.27            4.670     7.280514     7.280514
# 17  119.905        60.94            8.116     4.189256         <NA>
# 18  124.777        94.25            4.669     7.282073     7.282073
# 19  133.097        60.92            8.117     4.188740         <NA>
# 20  137.968        94.19            4.668     7.283633     7.283633
# 21  146.288        60.85            8.116     4.189256         <NA>
# 22  151.160        94.09            4.669     7.282073     7.282073
# 23  159.479        60.76            8.116     4.189256         <NA>
# 24  164.352        94.05            4.669     7.282073     7.282073
# 25  172.672        60.83            8.118     4.188224         <NA>
# 26  177.544        94.09            4.670     7.280514     7.280514
# 27  185.863        60.72            8.117     4.188740         <NA>
# 28  199.054        60.83           12.989     2.617600       2.6176
# 29  203.926        94.11            4.668     7.283633         <NA>
# 30  212.246        60.84            8.117     4.188740      4.18874
# 31  217.118        94.05            4.669     7.282073         <NA>
# 32  225.437        60.84            8.116     4.189256     4.189256
# 33  230.309        94.01            4.669     7.282073         <NA>
# 34  238.628        60.99            8.116     4.189256     4.189256
# 35  243.501        94.07            4.669     7.282073         <NA>
# 36  252.023        60.56            8.320     4.086538     4.086538
# 37  257.098        94.45            4.872     6.978654         <NA>
# 38  265.621        60.77            8.320     4.086538     4.086538
# 39  270.696        94.50            4.872     6.978654         <NA>
# 40  279.218        60.88            8.319     4.087030      4.08703
# 41  284.294        94.53            4.873     6.977221         <NA>
# 42  293.018        60.96            8.522     3.989674     3.989674
# 43  297.890        94.53            4.872     6.978654         <NA>
# 44  306.616        60.62            8.523     3.989206     3.989206
# 45  311.691        94.43            4.872     6.978654         <NA>
# 46  320.416        60.56            8.522     3.989674     3.989674
# 47  325.491        94.40            4.872     6.978654         <NA>
# 48  334.014        60.96            8.320     4.086538     4.086538
# 49  339.089        94.49            4.872     6.978654         <NA>
# 50  347.814        60.65            8.522     3.989674     3.989674
# 51  352.889        94.36            4.872     6.978654         <NA>
# 52  361.615        60.97            8.523     3.989206     3.989206
# 53  366.487        94.48            4.872     6.978654         <NA>
# 54  375.213        60.70            8.523     3.989206     3.989206
# 55  380.288        94.36            4.873     6.977221         <NA>
# 56  389.012        60.60            8.522     3.989674     3.989674
# 57  394.088        94.33            4.872     6.978654         <NA>
# 58  402.812        60.59            8.521     3.990142     3.990142
#
#    cooling rate
# 0          <NA>
# 1      4.088504
# 2          <NA>
# 3      3.991079
# 4          <NA>
# 5      4.088996
# 6          <NA>
# 7      4.088996
# 8          <NA>
# 9      4.190805
# 10         <NA>
# 11     4.189772
# 12         <NA>
# 13     4.189772
# 14         <NA>
# 15      4.18874
# 16         <NA>
# 17     4.189256
# 18         <NA>
# 19      4.18874
# 20         <NA>
# 21     4.189256
# 22         <NA>
# 23     4.189256
# 24         <NA>
# 25     4.188224
# 26         <NA>
# 27      4.18874
# 28         <NA>
# 29     7.283633
# 30         <NA>
# 31     7.282073
# 32         <NA>
# 33     7.282073
# 34         <NA>
# 35     7.282073
# 36         <NA>
# 37     6.978654
# 38         <NA>
# 39     6.978654
# 40         <NA>
# 41     6.977221
# 42         <NA>
# 43     6.978654
# 44         <NA>
# 45     6.978654
# 46         <NA>
# 47     6.978654
# 48         <NA>
# 49     6.978654
# 50         <NA>
# 51     6.978654
# 52         <NA>
# 53     6.978654
# 54         <NA>
# 55     6.977221
# 56         <NA>
# 57     6.978654
# 58         <NA>
# C:\Users\sa200\AppData\Local\Temp\ipykernel_3016\4135007064.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['heating rate'] = pd.NA
# C:\Users\sa200\AppData\Local\Temp\ipykernel_3016\4135007064.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['cooling rate'] = pd.NA

# %%
# # Drop rows only if both 'heating rate' and 'cooling rate' are NA
# cleaned_df.dropna(subset=['heating rate', 'cooling rate'], how='all', inplace=True)

# # Replace NA in both columns with a placeholder, e.g., 0
# cleaned_df['heating rate'].fillna(0, inplace=True)
# cleaned_df['cooling rate'].fillna(0, inplace=True)

# # Create a combined metric example
# cleaned_df['combined rate'] = cleaned_df['heating rate'].fillna(0) + cleaned_df['cooling rate'].fillna(0)


# print(cleaned_df)

# %%
# Extract the base name without extension
base_name = os.path.splitext(os.path.basename(input_path))[0]

# Create a new output filename using the base name
output_path = f'./Excel/{base_name}_output.xlsx'

# Write the cleaned dataframe to a new Excel file
cleaned_df.to_excel(output_path, index=False, engine='openpyxl')

# %%
# cleaned_df['heating rate'] = cleaned_df[(cleaned_df['calculation'] >= 5)]

# print(cleaned_df)
