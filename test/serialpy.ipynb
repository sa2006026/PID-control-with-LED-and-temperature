# %%
import serial
import time

# Set up serial connection (adjust 'COM3' to the port your Arduino is connected to)
ser = serial.Serial('COM3', 9600, timeout=1)
time.sleep(2)  # Wait for connection to establish

# %%
with open("data.txt", "w") as file:
        while True:
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').rstrip()
                print(line)  # Print to console (optional)
                file.write(line + '\n')
                file.flush()  # Ensure data is written to the file
# Out:
# PT100: 25.77
# Temperature: 8388170.00
# Temperature: 8388151.00
# Temperature: 8388115.00
# Temperature: 8388074.00
# Temperature: 8388006.00
# Temperature: 8387976.00
# Temperature: 8388004.00
# Temperature: 8388015.00
# Temperature: 8388048.00
# Temperature: 8388116.00
# Temperature: 8388132.00
# Temperature: 8388218.00
# Temperature: 8388225.00
# Temperature: 8388270.00
# Temperature: 8388276.00
# Temperature: 8388340.00
# Temperature: 8388404.00
# Temperature: 8388394.00
# Temperature: 8388316.00
# Temperature: 8388273.00
# Temperature: 8388237.00
# Temperature: 8387954.00
# Temperature: 8387776.00
# Temperature: 8387677.00
# Temperature: 8387707.00
# Temperature: 8387676.00
# Temperature: 8387677.00
# Temperature: 8387772.00
# Temperature: 8387819.00
# Temperature: 8387835.00
# Temperature: 8387935.00
# Temperature: 8387919.00
# Temperature: 8387912.00
# Temperature: 8387843.00
# Temperature: 8387860.00
# Temperature: 8387857.00
# Temperature: 8387925.00
# Temperature: 8387857.00
# Temperature: 8387905.00
# Temperature: 8387901.00
# Temperature: 8387940.00
# Temperature: 8387878.00
# Temperature: 8387763.00
# Temperature: 8387696.00
# Temperature: 8387545.00
# Temperature: 8387486.00
# Temperature: 8387496.00
# Temperature: 8387549.00
# Temperature: 8387491.00
# Temperature: 8387267.00
# Temperature: 8386885.00
# Temperature: 8386652.00
# Temperature: 8386467.00
# Temperature: 8386370.00
# Temperature: 8386292.00
# Temperature: 8386335.00
# Temperature: 8386346.00
# Temperature: 8386387.00
# Temperature: 8386362.00
# Temperature: 8386338.00
# Temperature: 8386321.00
# Temperature: 8386324.00
# Temperature: 8386344.00
# Temperature: 8386396.00
# Temperature: 8386475.00
# Temperature: 8386520.00
# Temperature: 8386540.00
# Temperature: 8386575.00
# Temperature: 8386595.00
# Temperature: 8386584.00
# Temperature: 8386592.00
# Temperature: 8386562.00
# Temperature: 8386448.00
# Temperature: 8386423.00
# Temperature: 8386434.00
# Temperature: 8386555.00
# Temperature: 8386585.00
# Temperature: 8386613.00
# Temperature: 8386657.00
# Temperature: 8386719.00
# Temperature: 8386740.00
# Temperature: 8386755.00
# Temperature: 8386823.00
# Temperature: 8386802.00
# Temperature: 8386859.00
# Temperature: 8386868.00
# Temperature: 8387010.00
# Temperature: 8387021.00
# Temperature: 8387088.00
# Temperature: 8387151.00
# Temperature: 8387175.00
# Temperature: 8387176.00
# Temperature: 8387224.00
# Temperature: 8387161.00
# Temperature: 8387106.00
# Temperature: 8387055.00
# Temperature: 8386960.00
# Temperature: 8386957.00
# Temperature: 8386966.00
# Temperature: 8387012.00
# Temperature: 8387041.00
# Temperature: 8387122.00
# Temperature: 8387198.00
# Temperature: 8387295.00
# Temperature: 8387329.00
# Temperature: 8387402.00
# Temperature: 8387409.00
# Temperature: 8387404.00
# Temperature: 8387334.00
# Temperature: 8387390.00
# Temperature: 8387379.00
# Temperature: 8387384.00
# Temperature: 8387480.00
# Temperature: 8387544.00
# Temperature: 8387628.00
# Temperature: 8387729.00
# Temperature: 8387738.00
# Temperature: 8387796.00
# Temperature: 8387811.00
# Temperature: 8387721.00
# Temperature: 8387536.00
# Temperature: 8387240.00
# Temperature: 8386979.00
# Temperature: 8387035.00
# Temperature: 8387184.00
# Temperature: 8387251.00
# Temperature: 8387300.00
# Temperature: 8387192.00
# Temperature: 8387150.00
# Temperature: 8387146.00
# Temperature: 8387164.00
# Temperature: 8387210.00
# Temperature: 8387205.00
# Temperature: 8387061.00
# Temperature: 8386941.00
# Temperature: 8386891.00
# Temperature: 8386883.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\sa200\Documents\PlatformIO\Projects\PID control with LED and temperature\src\serialpy.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/sa200/Documents/PlatformIO/Projects/PID%20control%20with%20LED%20and%20temperature/src/serialpy.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> with open("data.txt", "w") as file:
#       <a href='vscode-notebook-cell:/c%3A/Users/sa200/Documents/PlatformIO/Projects/PID%20control%20with%20LED%20and%20temperature/src/serialpy.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a>         while True:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sa200/Documents/PlatformIO/Projects/PID%20control%20with%20LED%20and%20temperature/src/serialpy.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>             if ser.in_waiting > 0:
#       <a href='vscode-notebook-cell:/c%3A/Users/sa200/Documents/PlatformIO/Projects/PID%20control%20with%20LED%20and%20temperature/src/serialpy.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>                 line = ser.readline().decode('utf-8').rstrip()
#       <a href='vscode-notebook-cell:/c%3A/Users/sa200/Documents/PlatformIO/Projects/PID%20control%20with%20LED%20and%20temperature/src/serialpy.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>                 print(line)  # Print to console (optional)
#
# File c:\Users\sa200\Documents\PlatformIO\Projects\PID control with LED and temperature\.env\lib\site-packages\serial\serialwin32.py:258, in Serial.in_waiting(self)
#     256 flags = win32.DWORD()
#     257 comstat = win32.COMSTAT()
# --> 258 if not win32.ClearCommError(self._port_handle, ctypes.byref(flags), ctypes.byref(comstat)):
#     259     raise SerialException("ClearCommError failed ({!r})".format(ctypes.WinError()))
#     260 return comstat.cbInQue
#
# KeyboardInterrupt:

# %%
ser.close()  # Close the serial connection when done
